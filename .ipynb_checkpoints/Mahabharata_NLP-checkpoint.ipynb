# %% [markdown]
# # Machine Learning Engineer Nanodegree
#
# ## Capstone Project
#
# ### Project: Semantic similarity extraction using word vectors in Mahabharata dataset

# %% [markdown]
# Welcome to the capstone project of the Machine Learning Engineer Nanodegree! In this notebook, we will use corpus of words from Mahabharata is used as an input to create word vectors using word2vec, with the help of t-SNE, reduce the dimensions of the word vectors and finally use cosine similarity to analyze semantic similarities, i.e. to answer relationship questions based on the learning. The end solution of this project will be to analyze relationships and logics in the dataset.
#
# The dataset for this project can be found on the [GitHub Mahabharata Machine Learning Repository](https://github.com/TilakD/Mahabharata_extract-semantic-similarities_Natural-languageprocessing/tree/master/Dataset)
#
# Model is assessed using the real facts about the data set, to benchmark the model I have compiled 23 relationship facts and will be adding few more as I build the model. For example, below are a few of the real data used to benchmark the model.
# Dhritarastra is related to Pandu, as Sahadeva is related to Nakula
#
#     Bhima is related to Arjuna, as Ambalika is related to Ambika
#     Pandu is related to Kunti, as Dhritarashtra is related to Gandhari
#     Bhima is related to Draupadi, as Arjuna is related to Chitrangada
#     Karna is related to Kunti, as Duryodhana is related to Gandhari
#     .
#     .
#     .
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ## Exploring the Data
# Run the code cell below to load necessary Python libraries.

# %%
#future is the missing compatibility layer between Python 2 and Python 3. 
#It allows you to use a single, clean Python 3.x-compatible codebase to 
#support both Python 2 and Python 3 with minimal overhead.
from __future__ import absolute_import, division, print_function

# %%
#encoding. word encodig
import codecs
#finds all pathnames matching a pattern, like regex
import glob
#log events for libraries
import logging
#concurrency
import multiprocessing
#dealing with operating system , like reading file
import os
#pretty print, human readable
import pprint
#regular expressions
import re
#natural language toolkit
import nltk
#word 2 vec
import gensim.models.word2vec as w2v
#dimensionality reduction
import sklearn.manifold
#math
import numpy as np
#plotting
import matplotlib.pyplot as plt
#parse dataset
import pandas as pd
#visualization
import seaborn as sns
# Out:
# C:\Users\DTILAK\AppData\Local\Continuum\Anaconda2\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set up logging

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# Download NLTK tokenizer models (only the first time)

# %%
##stopwords like the at a an, unnecesasry
##tokenization into sentences, punkt 
##http://www.nltk.org/

nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DTILAK\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DTILAK\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Prepare Corpus
# Load books from files

# %%
#get the book names, matching txt file
book_filenames = sorted(glob.glob("..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\*.txt"))
print("Found books:")
book_filenames
# Out:
# Found books:
# ['..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\1.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\10.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\11.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\12.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\13.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\14.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\15.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\16.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\17.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\18.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\2.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\3.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\4.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\5.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\6.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\7.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\8.txt',
#  '..\\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\\input\\9.txt']

# %% [markdown]
# Combine the books into one string

# %%
#step 1 process data

#initialize raw unicode , we'll add all text to this file in memory
corpus_raw = u""

#for each book, read it, open it un utf 8 format, 
#add it to the raw corpus
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print ("Corpus is now {0} characters long".format(len(corpus_raw)))
    print ()
# Out:
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\1.txt'...
# Corpus is now 295412 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\10.txt'...
# Corpus is now 325640 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\11.txt'...
# Corpus is now 337972 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\12.txt'...
# Corpus is now 364937 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\13.txt'...
# Corpus is now 390015 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\14.txt'...
# Corpus is now 404662 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\15.txt'...
# Corpus is now 417222 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\16.txt'...
# Corpus is now 447521 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\17.txt'...
# Corpus is now 476028 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\18.txt'...
# Corpus is now 478927 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\2.txt'...
# Corpus is now 682505 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\3.txt'...
# Corpus is now 828766 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\4.txt'...
# Corpus is now 936868 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\5.txt'...
# Corpus is now 1052238 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\6.txt'...
# Corpus is now 1349941 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\7.txt'...
# Corpus is now 1594913 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\8.txt'...
# Corpus is now 1664898 characters long
#
# Reading '..\Mahabharata_extract-semantic-similarities_Natural-languageprocessing\input\9.txt'...
# Corpus is now 1706632 characters long

# %% [markdown]
# Split the corpus into sentences

# %%
#tokenizastion! saved the trained model here
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
#tokenize into sentences
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#remove unnnecessary, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# Above all these qualities, he was a devoted servant of Lord Vishnu, and therefore he was given the title, "King of kings".
# [u'Above', u'all', u'these', u'qualities', u'he', u'was', u'a', u'devoted', u'servant', u'of', u'Lord', u'Vishnu', u'and', u'therefore', u'he', u'was', u'given', u'the', u'title', u'King', u'of', u'kings']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 293,755 tokens

# %% [markdown]
# Train Word2Vec

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 300
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
mahabharata2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
mahabharata2vec.build_vocab(sentences)
# Out:
# 2017-03-21 02:32:36,885 : INFO : collecting all words and their counts
# 2017-03-21 02:32:36,885 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-03-21 02:32:36,927 : INFO : PROGRESS: at sentence #10000, processed 165878 words, keeping 9238 word types
# 2017-03-21 02:32:36,963 : INFO : collected 11439 word types from a corpus of 293755 raw words and 17725 sentences
# 2017-03-21 02:32:36,963 : INFO : Loading a fresh vocabulary
# 2017-03-21 02:32:36,986 : INFO : min_count=3 retains 5703 unique words (49% of original 11439, drops 5736)
# 2017-03-21 02:32:36,987 : INFO : min_count=3 leaves 286413 word corpus (97% of original 293755, drops 7342)
# 2017-03-21 02:32:37,010 : INFO : deleting the raw counts dictionary of 11439 items
# 2017-03-21 02:32:37,013 : INFO : sample=0.001 downsamples 52 most-common words
# 2017-03-21 02:32:37,013 : INFO : downsampling leaves estimated 214323 word corpus (74.8% of prior 286413)
# 2017-03-21 02:32:37,016 : INFO : estimated required memory for 5703 words and 300 dimensions: 16538700 bytes
# 2017-03-21 02:32:37,040 : INFO : resetting layer weights

# %%
print("Word2Vec vocabulary length:", len(mahabharata2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 5703

# %% [markdown]
# Start training, this might take a minute or two...

# %%
mahabharata2vec.train(sentences)
# Out:
# 2017-03-21 02:32:37,255 : INFO : training model with 4 workers on 5703 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2017-03-21 02:32:37,255 : INFO : expecting 17725 sentences, matching count from corpus used for vocabulary survey
# 2017-03-21 02:32:38,316 : INFO : PROGRESS: at 16.13% examples, 166568 words/s, in_qsize 7, out_qsize 0
# 2017-03-21 02:32:39,348 : INFO : PROGRESS: at 32.60% examples, 167379 words/s, in_qsize 7, out_qsize 0
# 2017-03-21 02:32:40,345 : INFO : PROGRESS: at 49.60% examples, 171951 words/s, in_qsize 8, out_qsize 0
# 2017-03-21 02:32:41,453 : INFO : PROGRESS: at 67.96% examples, 175218 words/s, in_qsize 8, out_qsize 0
# 2017-03-21 02:32:42,444 : INFO : PROGRESS: at 85.12% examples, 175567 words/s, in_qsize 7, out_qsize 0
# 2017-03-21 02:32:43,336 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2017-03-21 02:32:43,352 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-03-21 02:32:43,410 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-03-21 02:32:43,460 : INFO : PROGRESS: at 100.00% examples, 173002 words/s, in_qsize 0, out_qsize 1
# 2017-03-21 02:32:43,461 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-03-21 02:32:43,463 : INFO : training on 1468775 raw words (1071487 effective words) took 6.2s, 172942 effective words/s
# 1071487

# %% [markdown]
# Save to file, can be useful later

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
mahabharata2vec.save(os.path.join("trained", "mahabharata2vec.w2v"))
# Out:
# 2017-03-21 02:32:43,555 : INFO : saving Word2Vec object under trained\mahabharata2vec.w2v, separately None
# 2017-03-21 02:32:43,555 : INFO : not storing attribute syn0norm
# 2017-03-21 02:32:43,555 : INFO : not storing attribute cum_table
# 2017-03-21 02:32:43,640 : INFO : saved trained\mahabharata2vec.w2v

# %% [markdown]
# Explore the trained model.

# %%
mahabharata2vec = w2v.Word2Vec.load(os.path.join("trained", "mahabharata2vec.w2v"))
# Out:
# 2017-03-21 02:32:43,655 : INFO : loading Word2Vec object from trained\mahabharata2vec.w2v
# 2017-03-21 02:32:43,740 : INFO : loading wv recursively from trained\mahabharata2vec.w2v.wv.* with mmap=None
# 2017-03-21 02:32:43,740 : INFO : setting ignored attribute syn0norm to None
# 2017-03-21 02:32:43,740 : INFO : setting ignored attribute cum_table to None
# 2017-03-21 02:32:43,740 : INFO : loaded trained\mahabharata2vec.w2v

# %% [markdown]
# Compress the word vectors into 2D space and plot them

# %%
#my video - how to visualize a dataset easily
tsne = sklearn.manifold.TSNE(n_components=3,perplexity=50.0, random_state=0)

# %%
all_word_vectors_matrix = mahabharata2vec.wv.syn0

# %% [markdown]
# Train t-SNE, this could take a minute or two...

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %% [markdown]
# Plot the big picture

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1], coords[2])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[mahabharata2vec.wv.vocab[word].index])
            for word in mahabharata2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y", "z"]
)

# %%
if not os.path.exists("points_output"):
    os.makedirs("points_output")
points.to_csv(os.path.join("points_output", "points_threeD.csv"), sep=',')

# %%
points.head(10)
# Out:
#           word         x         y         z
# 0      raining  0.424918 -6.349219  5.431699
# 1       yellow  1.783615 -0.206495  1.290355
# 2         four -2.278208 -0.361083  1.760288
# 3        woods  2.252374 -4.694518  5.074349
# 4      hanging  3.258187 -1.045073  5.657058
# 5      looking -0.009951 -0.192818  5.023404
# 6     granting  3.879353 -5.591186  3.636723
# 7     eligible  0.097381 -7.451119  0.907763
# 8  Kundadahara  2.585767 -0.774595  6.648456
# 9         lord  3.784586 -2.931360 -0.342055

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", c = "z",s=10, figsize=(12, 12))

# %%
all_words = points.word
all_words_df = pd.DataFrame(all_words)
all_words_list = all_words_df['word'].values.tolist()
str_words = ' '.join(all_words_list)
#str_words

# %%
essays = str_words
tokens = nltk.word_tokenize(essays)
tagged = nltk.pos_tag(tokens)
nouns = [word for word,pos in tagged if (pos == 'NNP')]
joined = "\n".join(nouns).encode('utf-8')
into_string = str(nouns)

output = open("Proper_noun.txt", "w")
output.write(joined)
output.close()

noun_string = " ".join(nouns).encode('utf-8')

# %%
number_noun = 0
noun_points = pd.DataFrame()
noun_string_to_word = sentence_to_wordlist(noun_string)
all_words = points.word

for noun_wrd in range(len(noun_string_to_word)):
    for wrd_sl_no in range(len(points)):
        if noun_string_to_word[noun_wrd] == all_words[wrd_sl_no]:
            noun_points_old = points.iloc[[wrd_sl_no]]
            noun_points = noun_points.append(noun_points_old)

# %%
type(noun_points)
#print (noun_points)
noun_points.to_csv(os.path.join("points_output", "noun_points_threeD.csv"), sep=',')
# Out:
#               word         x         y         z
# 8      Kundadahara  2.585767 -0.774595  6.648456
# 23     Madhusudana  2.483147 -3.930126  0.651486
# 38           Three -4.628896  3.068068  3.328383
# 55          Person  0.198201 -0.748825 -2.585699
# 61            Meru -1.531851 -5.071883  3.738883
# 66          Aindra -0.130422 -0.786963  2.329905
# 90        Bhagavad -0.004062 -0.508860 -2.869101
# 99          Pitris  0.709916 -5.535454  7.227348
# 101            Him -1.494276  2.946386 -3.395107
# 104     Gandharvas -0.699611  2.487892  1.998519
# 109          Shame  2.602863 -7.333992  2.255838
# 112          Shami  1.473273 -1.784857  5.526929
# 113          Curse -4.055677  2.665827  4.692852
# 123      Vaishnava -0.727071 -6.854807 -3.042829
# 128         Sankha  2.249680 -0.889455  6.635501
# 133     Srutakirti  2.779010 -1.609005  7.372550
# 135         Please  4.449821 -3.411736 -1.595799
# 136            Due  3.790702 -7.372793 -1.888071
# 146      Sikhandin  1.425403 -2.817425  7.005847
# 150    Arishtasena  1.761728 -5.823908  6.235257
# 154        Victory  0.778445 -8.296551  5.282132
# 155      Satyavati  5.451993 -1.698111  3.203636
# 163      Gradually  0.334780 -3.252191  5.813207
# 164      Generally -0.179575 -6.686041  3.718695
# 166      Parikshit  1.798979 -5.503609  1.973764
# 181       Kauravas  0.857285  2.975676  3.164456
# 194    Chakravyuha  0.640048 -3.103754  2.904746
# 195   Nevertheless  0.992506 -5.720403  6.213796
# 199     Duhshasana -3.235808  1.089505  2.616898
# 200           Siva -1.936837  4.073285 -1.245491
# ...            ...       ...       ...       ...
# 5500    Dvaitavana  2.966012 -0.497352  3.965093
# 5508         Vedas  0.447578 -2.849206 -3.906996
# 5514      Colossal -4.033086  2.644152  4.759051
# 5516       Siddhas  0.077407 -4.106750  6.275648
# 5517         Earth -0.859387 -3.820626  1.202482
# 5520         Whose  2.174375 -6.104793  4.011949
# 5531       Manipur  0.603220 -0.758733  6.252132
# 5539       Abandon  0.842106 -8.187359  4.901845
# 5563    Shrinjayas -0.642039  2.371323  1.940489
# 5566      Sudharma  2.739269 -2.928169  3.852072
# 5584       Mangled  3.140745 -2.721715  7.553525
# 5586      Sauptika -4.360807  2.941271  3.932727
# 5590     Pradyumna -1.171499  1.300425  3.314207
# 5603       Prabhas  1.286447 -4.271091  4.382809
# 5621    Chitrasena -2.609017  1.362750  2.417639
# 5623       Besides  2.493707 -6.682847 -0.268275
# 5634           Sun  2.121478 -3.395345  4.900254
# 5640         Vyasa  4.875445 -0.588897  2.888744
# 5641      Trigarta -2.004470  1.789311  2.757786
# 5648       Greatly -1.949097  0.740093  2.044355
# 5665      Sutasoma -1.000389  0.455867  3.012182
# 5667     Susharman -2.835636  1.340066  2.414392
# 5668          Bali  3.138559 -5.363873  2.564193
# 5669          Upon -4.100475  3.410774  3.034670
# 5673     Jamadagni  4.961480 -4.216903  4.432471
# 5674     Following  5.157317 -2.236619  4.611302
# 5677           Ten -4.418633  2.977505  3.809277
# 5689      Bharatas  4.571848 -5.139423  0.364197
# 5692          Five -4.429456  2.979746  3.791569
# 5700          Sita -1.643039 -6.215766  4.969080
#
# [834 rows x 4 columns]

# %%
noun_points.plot.scatter("x", "y", c = "z", s=20, figsize=(12, 12))

# %%
def plot_region(x_bounds, y_bounds):
    slice = noun_points[
        (x_bounds[0] <= points.x) &
        (noun_points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (noun_points.y <= y_bounds[1])
    ]
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(15, 15))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %%
plot_region(x_bounds=(-8, 8.2), y_bounds=(0.2,1.5))
# Out:
# C:\Users\DTILAK\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
#All
plot_region(x_bounds=(-10, 8.2), y_bounds=(-10,6))
savefig('foo.pdf')
# Out:
# C:\Users\DTILAK\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# Explore semantic similarities between book characters. Words closest to the given word

# %%
mahabharata2vec.most_similar("Krishna")
# Out:
# 2017-03-21 02:37:14,056 : INFO : precomputing L2-norms of word weight vectors
# [(u'Balarama', 0.7886941432952881),
#  (u'Daruka', 0.7710659503936768),
#  (u'Rama', 0.7675768733024597),
#  (u'Shri', 0.7643648386001587),
#  (u'Maha', 0.7574467062950134),
#  (u'mantra', 0.753020703792572),
#  (u'Baladeva', 0.7400621771812439),
#  (u'Keshava', 0.7350532412528992),
#  (u'Shiva', 0.7335325479507446),
#  (u'eyed', 0.7326822280883789)]

# %%
mahabharata2vec.most_similar("Arjuna")
# Out:
# [(u'Partha', 0.8264423608779907),
#  (u'Daruka', 0.8240310549736023),
#  (u'Satyaki', 0.7683112621307373),
#  (u'Parashurama', 0.7564795017242432),
#  (u'Shishupala', 0.7510733604431152),
#  (u'Bhima', 0.7496506571769714),
#  (u'Pradyumna', 0.7487268447875977),
#  (u'Shalva', 0.7469387054443359),
#  (u'Kumara', 0.7468728423118591),
#  (u'Kuvera', 0.7465615272521973)]

# %%
mahabharata2vec.most_similar("Karna")
# Out:
# [(u'Ashvatthama', 0.9268690943717957),
#  (u'Drona', 0.8998265862464905),
#  (u'Salya', 0.8947164416313171),
#  (u'Kripa', 0.8854435682296753),
#  (u'Bhishma', 0.8741419911384583),
#  (u'Jayadratha', 0.8694705963134766),
#  (u'Parashurama', 0.8583049178123474),
#  (u'Shakuni', 0.857813835144043),
#  (u'preceptor', 0.8561322093009949),
#  (u'Kritavarman', 0.8512133359909058)]

# %%
mahabharata2vec.most_similar("Vrishasena")
# Out:
# [(u'Sala', 0.9825860857963562),
#  (u'Bhurishrava', 0.9762349128723145),
#  (u'Brihadvala', 0.9735701680183411),
#  (u'Vikarna', 0.9717980623245239),
#  (u'Bahlika', 0.9671539068222046),
#  (u'Chitrasena', 0.9667435884475708),
#  (u'Chekitana', 0.9606934189796448),
#  (u'Satanika', 0.9585724472999573),
#  (u'assaulted', 0.955649733543396),
#  (u'Greatly', 0.9537089467048645)]

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = mahabharata2vec.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("Dhritarastra" ,"Pandu", "Nakula")
nearest_similarity_cosmul("Bhima" ,"Arjuna", "Ambika")
nearest_similarity_cosmul("Pandu" ,"Kunti", "Gandhari")
nearest_similarity_cosmul("Bhima" ,"Draupadi", "Chitrangada")
nearest_similarity_cosmul("Karna" ,"Kunti", "Gandhari")
nearest_similarity_cosmul("Bhima" ,"Draupadi", "Subhadra")
nearest_similarity_cosmul("Yudhisthira" ,"Kunti", "Gandhari")
nearest_similarity_cosmul("Bhima" ,"Kunti", "Madri")
nearest_similarity_cosmul("Bhima" ,"Draupadi", "Ulupi")
nearest_similarity_cosmul("Vichitravirya" ,"Ambalika", "Ambika")
nearest_similarity_cosmul("Bhima" ,"Ghatotkacha", "Abhimanyu")
nearest_similarity_cosmul("Bhima" ,"Draupadi", "Draupadi")
# Out:
# Dhritarastra is related to Pandu, as Sahadeva is related to Nakula
# Bhima is related to Arjuna, as dressed is related to Ambika
# Pandu is related to Kunti, as loss is related to Gandhari
# Bhima is related to Draupadi, as invoked is related to Chitrangada
# Karna is related to Kunti, as Kripa is related to Gandhari
# Bhima is related to Draupadi, as Partha is related to Subhadra
# Yudhisthira is related to Kunti, as Duryodhana is related to Gandhari
# Bhima is related to Kunti, as rushed is related to Madri
# Bhima is related to Draupadi, as Partha is related to Ulupi
# Vichitravirya is related to Ambalika, as Chitrangada is related to Ambika
# Bhima is related to Ghatotkacha, as tolerating is related to Abhimanyu
# Bhima is related to Draupadi, as Rakshasa is related to Draupadi
# u'Rakshasa'
